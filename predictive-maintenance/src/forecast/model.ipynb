# %% [markdown]
# # Time-Series Forecasting with Deep Learning for Predictive Maintenance
#
# This notebook is the Kaggle notebook version of the notebook I uploaded in [my Github](https://github.com/jegun19/predictive_maintenance)

# %% [markdown]
# ## Select one machine
# In this step, we will take a look at the overall characteristic of the data, and then select one machine that we want to analyze and use for doing the predictive maintenance task.

# %%
# Load all csv datas using pandas
import os
import pandas as pd

WORKING_DIR = "../../data/"

df_tele = pd.read_csv(WORKING_DIR + 'PdM_telemetry.csv')
df_fail = pd.read_csv(WORKING_DIR + 'PdM_failures.csv')
df_err = pd.read_csv(WORKING_DIR + 'PdM_errors.csv')
df_maint = pd.read_csv(WORKING_DIR + 'PdM_maint.csv')

# %%
# print the top 5 rows from the failure dataframe
df_fail.head(n=5)
# Out:
#               datetime  machineID failure
# 0  2015-01-05 06:00:00          1   comp4
# 1  2015-03-06 06:00:00          1   comp1
# 2  2015-04-20 06:00:00          1   comp2
# 3  2015-06-19 06:00:00          1   comp4
# 4  2015-09-02 06:00:00          1   comp4

# %% [markdown]
# For simplicity purpose, we will select a single machine that we are going to use for analysis. In this notebook, we will select machine number 11.

# %%
df_sel = df_tele.loc[df_tele['machineID'] == 11].reset_index(drop=True)
df_sel.head(n=5)
# Out:
#               datetime  machineID        volt      rotate    pressure  \
# 0  2015-01-01 06:00:00         11  164.039259  389.699577  113.619975
# 1  2015-01-01 07:00:00         11  180.325510  409.788550   97.506203
# 2  2015-01-01 08:00:00         11  146.917119  420.626012   97.087205
# 3  2015-01-01 09:00:00         11  164.895416  426.409611   86.494413
# 4  2015-01-01 10:00:00         11  174.330072  471.774231  109.277816
#
#    vibration
# 0  29.775109
# 1  40.512160
# 2  33.420937
# 3  40.263365
# 4  39.931749

# %% [markdown]
# Then, we will look into the error and failure record and then filter it only to show records belonging to machine number 11.

# %%
# Check failure record of machine 11
sel_fail = df_fail.loc[df_fail['machineID'] == 11]
pd.DataFrame(sel_fail)
# Out:
#                datetime  machineID failure
# 58  2015-01-20 06:00:00         11   comp2
# 59  2015-02-19 06:00:00         11   comp3
# 60  2015-04-20 06:00:00         11   comp2
# 61  2015-04-20 06:00:00         11   comp3
# 62  2015-10-02 06:00:00         11   comp3
# 63  2015-12-16 06:00:00         11   comp3

# %%
# Check error record of machine 11
sel_err = df_err.loc[df_err['machineID'] == 11]
pd.DataFrame(sel_err).head()
# Out:
#                 datetime  machineID errorID
# 360  2015-01-19 06:00:00         11  error2
# 361  2015-01-19 06:00:00         11  error3
# 362  2015-02-15 01:00:00         11  error4
# 363  2015-02-18 06:00:00         11  error4
# 364  2015-02-26 23:00:00         11  error4

# %% [markdown]
# From the explanation regarding the difference between failure and error in Kaggle, it is described that error refers to non-breaking events while failure refers to events that cause the machine to fail. Then, we will see in chronological plot how does the two events relate to each other.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

fig, ax = plt.subplots()

# For a simpler plot, we will use two different values in the y-axis to differentiate between error and failure
y_category = list()

for iter in range(0, len(sel_fail)):
  y_category.append('Failure')

for iter in range(0, len(sel_err)):
  y_category.append('Error')

# Get timestamp from error and selected failure
df_timestamp = pd.concat([sel_fail['datetime'], sel_err['datetime']], ignore_index=True, axis=0)
df_plot = pd.DataFrame({"timestamp": df_timestamp, "category": y_category})
df_plot.loc[:, 'timestamp'] = pd.to_datetime(df_plot.loc[:, 'timestamp'])
df_plot.sort_values(by=['timestamp'], inplace=True, ignore_index=True)


# Plot the data with timestamp as x-axis
ax.scatter('timestamp', 'category', data = df_plot)
yearfmt = mdates.DateFormatter('%Y-%m-%d')
ax.xaxis.set_major_formatter(yearfmt)
ax.tick_params(axis='x', rotation=45)
ax.grid()

# %% [markdown]
# From the plot above, we can see that failures are oftentimes preceded by error in the machine. However, not all error result in immediate failures. Some time may passes before the failure in machine occurs. Thus, in the next step, we are going to focus on the failure data and check which feature is affected by machine's failure.

# %% [markdown]
# ## Feature check
# Here, we will select the time window from the failure record, then plot each feature and check their response in the event of failures.

# %%
import datetime
# Change datatype of the timestamp column from object to datetime
df_sel.loc[:, 'datetime'] = pd.to_datetime(df_sel.loc[:, 'datetime'])

# Select the date to check from failure records
st = df_sel.loc[df_sel['datetime'] == datetime.datetime(2015, 2, 19)].index.values[0]

# Then, filter the telemetry data by the date and allow 7 days before and after
# the error occurs to observe any abnormalities.
select = df_sel.loc[st-7*24:st + 7*24,:]

# Plot volt and rotation feature
fig, ax = plt.subplots(nrows=2, sharex=True)
ax[0].plot('datetime', 'volt', data=select)
ax[0].set_ylabel("Volt")

ax[1].plot('datetime', 'rotate', data=select)
ax[1].tick_params(axis='x', rotation=45)
ax[1].set_xlabel("Timestamp")
ax[1].set_ylabel("Rotation")
# Out:
# Text(0, 0.5, 'Rotation')

# %% [markdown]
# As we observe volt and rotation readings, no noticeable anomalies are shown around the period of 2015-02-19. Then, next we will check both pressure and vibration features by plotting them.

# %%
# Plot pressure and vibration feature
fig, ax = plt.subplots(nrows=2, sharex=True)
ax[0].plot('datetime', 'pressure', data=select)
ax[0].set_ylabel("Pressure")

ax[1].plot('datetime', 'vibration', data=select)
ax[1].tick_params(axis='x', rotation=45)
ax[1].set_xlabel("Timestamp")
ax[1].set_ylabel("Vibration")
# Out:
# Text(0, 0.5, 'Vibration')

# %% [markdown]
# Between pressure and vibration, abnormality around the period of 2015-02-19 is more noticeable. Thus, in the next step, we will use <font color='red'>**pressure**</font> as feature and predictor.

# %% [markdown]
# ## Check autocorrelation and partial autocorrelation
# In time-series data, it is beneficial to check the autocorrelation and partial autocorrelation function of the data that will influence our model selection and parameter selection.

# %%
# Import plotting function
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Autocorrelation plot
plot_acf(df_sel['pressure'], lags = 40)
plt.show()

# %% [markdown]
# From the autocorrelation plot, we can see that the data is positively correlated up to lags of 40, where the autocorrelation value itself is quite low, indicating that the data does not have a strong autocorrelation properties.

# %%
# Partial autocorrelation plot
plot_pacf(df_sel['pressure'], lags = 40)
plt.show()

# %% [markdown]
# From the partial autocorrelation plot, the correlation between values of two different points in time is also quite weak, decaying to zero starting in the 15th lags. This information will be used in determining the lag in the model.

# %% [markdown]
# # Model Selection

# %% [markdown]
# ## Prepare data input and output
# In this notebook, we will use LSTM model, one of the famous prediction model in time-series forecasting task. To use it, first we need to provide input and output data in the correct format.

# %% [markdown]
# For our experiment, we will use training data of 1 month containing 2015-02-19 period where failure happened to predict another failure which occurs at 2015-04-20 according to the failure record. The feature used will be the pressure reading and timestamp (one-hot encoded).

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Select the date to check from failure records
st_train = df_sel.loc[df_sel['datetime'] == datetime.datetime(2015, 2, 19)].index.values[0]

# Then, filter the data to include approximately one month window
start_period = st_train - 14*24
end_period = st_train + 14*24

def create_feature(start, end):
  # create features from the selected machine
  pressure = df_sel.loc[start: end, 'pressure']
  timestamp = pd.to_datetime(df_sel.loc[start: end, 'datetime'])
  timestamp_hour = timestamp.map(lambda x: x.hour)
  timestamp_dow = timestamp.map(lambda x: x.dayofweek)

  # apply one-hot encode for timestamp data
  timestamp_hour_onehot = pd.get_dummies(timestamp_hour).to_numpy()

  # apply min-max scaler to numerical data
  scaler = MinMaxScaler()
  pressure = scaler.fit_transform(np.array(pressure).reshape(-1,1))

  # combine features into one
  feature = np.concatenate([pressure, timestamp_hour_onehot], axis=1)

  X = feature[:-1]
  y = np.array(feature[5:,0]).reshape(-1,1)

  return X, y, scaler

X, y, pres_scaler = create_feature(start_period, end_period)

# %% [markdown]
# Then, we need to shape the input further into a sequence (3-dimensional numpy array). We will use a function to return input and output sequence where each input sequence consists of 5-points observation. Simply put, observations of the <font color='red'>**past five hours**</font>  will be used to predict the sensor reading for the next <font color='red'>**one hour**</font> .

# %%
def shape_sequence(arr, step, start):
    out = list()
    for i in range(start, arr.shape[0]):
        low_lim = i
        up_lim = low_lim + step
        out.append(arr[low_lim: up_lim])

        if up_lim == arr.shape[0]:
          # print(i)
          break

    out_seq = np.array(out)
    return out_seq

# Shape the sequence according to the length specified
X_seq = shape_sequence(X, 5, 0)
y_seq = shape_sequence(y, 1, 0)

# Separate the input and output for train and validation
X_train, X_val, y_train, y_val = train_test_split(X_seq, y_seq, test_size=0.2, shuffle=False)

print("Training data shape = ", X_train.shape)
print("Validation data shape = ", X_val.shape)
# Out:
# Training data shape =  (534, 5, 25)
# Validation data shape =  (134, 5, 25)

# %% [markdown]
# ## Create prediction model

# %% [markdown]
# Create a simple 2-layer LSTM model with input shape matching the shape of the data sequence provided.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow.keras.losses as loss


def create_model(X_train, y_train):
  shape = X_train.shape[1]
  feat_length = X_train.shape[2]

  model = Sequential()
  model.add(LSTM(shape, activation='tanh', input_shape=(shape, feat_length), return_sequences=True))
  model.add(LSTM(shape, activation='tanh', input_shape=(shape, feat_length), return_sequences=False))
  model.add(Dense(shape, activation='relu'))
  model.add(Dense(1, activation='linear'))
  model.compile(optimizer=Adam(lr=0.035),
                loss=loss.mean_squared_error)
  model.fit(X_train, y_train, verbose=1, epochs=500)

  return model

model = create_model(X_train, y_train)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/500
# 17/17 [==============================] - 4s 16ms/step - loss: 0.1845
# Epoch 2/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.1131
# Epoch 3/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0505
# Epoch 4/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0270
# Epoch 5/500
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0244
# Epoch 6/500
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0231
# Epoch 7/500
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0222
# Epoch 8/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0218
# Epoch 9/500
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0215
# Epoch 10/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0213
# Epoch 11/500
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0211
# Epoch 12/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0210
# Epoch 13/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0208
# Epoch 14/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0207
# Epoch 15/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0206
# Epoch 16/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0205
# Epoch 17/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0204
# Epoch 18/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0202
# Epoch 19/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0200
# Epoch 20/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0201
# Epoch 21/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0202
# Epoch 22/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0197
# Epoch 23/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0195
# Epoch 24/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0196
# Epoch 25/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0194
# Epoch 26/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0193
# Epoch 27/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0191
# Epoch 28/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0188
# Epoch 29/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0186
# Epoch 30/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0185
# Epoch 31/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0182
# Epoch 32/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0180
# Epoch 33/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0179
# Epoch 34/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0177
# Epoch 35/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0178
# Epoch 36/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0173
# Epoch 37/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0172
# Epoch 38/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0169
# Epoch 39/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0168
# Epoch 40/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0167
# Epoch 41/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0167
# Epoch 42/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0164
# Epoch 43/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0165
# Epoch 44/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0163
# Epoch 45/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0162
# Epoch 46/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0164
# Epoch 47/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0166
# Epoch 48/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0164
# Epoch 49/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0161
# Epoch 50/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0162
# Epoch 51/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 52/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 53/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0159
# Epoch 54/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0160
# Epoch 55/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0159
# Epoch 56/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 57/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 58/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0159
# Epoch 59/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0160
# Epoch 60/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0160
# Epoch 61/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0158
# Epoch 62/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 63/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 64/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0158
# Epoch 65/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0158
# Epoch 66/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 67/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0159
# Epoch 68/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 69/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0159
# Epoch 70/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0157
# Epoch 71/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 72/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0157
# Epoch 73/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 74/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0157
# Epoch 75/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 76/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 77/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0156
# Epoch 78/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 79/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 80/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 81/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0157
# Epoch 82/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 83/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0158
# Epoch 84/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 85/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0156
# Epoch 86/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0155
# Epoch 87/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0155
# Epoch 88/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0155
# Epoch 89/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0155
# Epoch 90/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0156
# Epoch 91/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0158
# Epoch 92/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0156
# Epoch 93/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0155
# Epoch 94/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0156
# Epoch 95/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0155
# Epoch 96/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 97/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 98/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0156
# Epoch 99/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0158
# Epoch 100/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 101/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0154
# Epoch 102/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0156
# Epoch 103/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 104/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0154
# Epoch 105/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0156
# Epoch 106/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0160
# Epoch 107/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 108/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 109/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 110/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0157
# Epoch 111/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0159
# Epoch 112/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 113/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0154
# Epoch 114/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0156
# Epoch 115/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 116/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 117/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 118/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 119/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0159
# Epoch 120/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 121/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 122/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 123/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 124/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 125/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 126/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0154
# Epoch 127/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 128/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0155
# Epoch 129/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 130/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 131/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 132/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 133/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 134/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0154
# Epoch 135/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 136/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0152
# Epoch 137/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 138/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 139/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 140/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 141/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 142/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0152
# Epoch 143/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0151
# Epoch 144/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 145/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 146/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 147/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0152
# Epoch 148/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 149/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 150/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 151/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0152
# Epoch 152/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0152
# Epoch 153/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 154/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0151
# Epoch 155/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 156/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0151
# Epoch 157/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 158/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0151
# Epoch 159/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0151
# Epoch 160/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0151
# Epoch 161/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 162/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0153
# Epoch 163/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0159
# Epoch 164/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0153
# Epoch 165/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 166/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 167/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 168/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0151
# Epoch 169/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0154
# Epoch 170/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0156
# Epoch 171/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 172/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 173/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0151
# Epoch 174/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 175/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 176/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 177/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 178/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 179/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 180/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0153
# Epoch 181/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 182/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 183/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 184/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0150
# Epoch 185/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 186/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 187/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 188/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 189/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 190/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0155
# Epoch 191/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0151
# Epoch 192/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 193/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 194/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 195/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0154
# Epoch 196/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0152
# Epoch 197/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 198/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 199/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 200/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 201/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 202/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 203/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0150
# Epoch 204/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0149
# Epoch 205/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0151
# Epoch 206/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0153
# Epoch 207/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 208/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 209/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0149
# Epoch 210/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0149
# Epoch 211/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0151
# Epoch 212/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0154
# Epoch 213/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 214/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 215/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 216/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 217/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0148
# Epoch 218/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 219/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0148
# Epoch 220/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0149
# Epoch 221/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0149
# Epoch 222/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 223/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0151
# Epoch 224/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 225/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 226/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 227/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 228/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 229/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 230/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0148
# Epoch 231/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 232/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 233/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 234/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0149
# Epoch 235/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 236/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 237/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 238/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0149
# Epoch 239/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 240/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 241/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0150
# Epoch 242/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0150
# Epoch 243/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 244/500
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0149
# Epoch 245/500
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0148
# Epoch 246/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0147
# Epoch 247/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 248/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 249/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 250/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 251/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 252/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 253/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 254/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 255/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 256/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 257/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 258/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 259/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 260/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 261/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 262/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 263/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 264/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0147
# Epoch 265/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0147
# Epoch 266/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0147
# Epoch 267/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 268/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 269/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 270/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0147
# Epoch 271/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0146
# Epoch 272/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 273/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0147
# Epoch 274/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0148
# Epoch 275/500
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0148
# Epoch 276/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0146
# Epoch 277/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0147
# Epoch 278/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0152
# Epoch 279/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0150
# Epoch 280/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 281/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0147
# Epoch 282/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0148
# Epoch 283/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0146
# Epoch 284/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 285/500
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0147
# Epoch 286/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 287/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0146
# Epoch 288/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0147
# Epoch 289/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0145
# Epoch 290/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 291/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0146
# Epoch 292/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 293/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 294/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 295/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 296/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0147
# Epoch 297/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 298/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 299/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 300/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 301/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 302/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0149
# Epoch 303/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 304/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0145
# Epoch 305/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 306/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 307/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 308/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 309/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 310/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 311/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0146
# Epoch 312/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 313/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 314/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0144
# Epoch 315/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0146
# Epoch 316/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0148
# Epoch 317/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 318/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 319/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 320/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 321/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 322/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 323/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0146
# Epoch 324/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 325/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 326/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 327/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 328/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0146
# Epoch 329/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 330/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 331/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0145
# Epoch 332/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0145
# Epoch 333/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 334/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 335/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0146
# Epoch 336/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 337/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 338/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 339/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 340/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 341/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 342/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0145
# Epoch 343/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 344/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0147
# Epoch 345/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 346/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0144
# Epoch 347/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 348/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 349/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 350/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 351/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 352/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0144
# Epoch 353/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 354/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0144
# Epoch 355/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 356/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 357/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 358/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0144
# Epoch 359/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 360/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 361/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0145
# Epoch 362/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 363/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 364/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 365/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 366/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 367/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 368/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 369/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 370/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 371/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 372/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 373/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 374/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0144
# Epoch 375/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 376/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 377/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0144
# Epoch 378/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 379/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 380/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 381/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 382/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 383/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 384/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 385/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 386/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 387/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0142
# Epoch 388/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 389/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 390/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 391/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 392/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 393/500
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0142
# Epoch 394/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 395/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0143
# Epoch 396/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 397/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 398/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 399/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 400/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 401/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 402/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0142
# Epoch 403/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 404/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 405/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 406/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 407/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 408/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0143
# Epoch 409/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0146
# Epoch 410/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 411/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 412/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0142
# Epoch 413/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 414/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0144
# Epoch 415/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 416/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 417/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 418/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 419/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 420/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 421/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 422/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0145
# Epoch 423/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 424/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 425/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0143
# Epoch 426/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 427/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0140
# Epoch 428/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 429/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0142
# Epoch 430/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 431/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 432/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0141
# Epoch 433/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0141
# Epoch 434/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0141
# Epoch 435/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 436/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 437/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 438/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0141
# Epoch 439/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0141
# Epoch 440/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 441/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0146
# Epoch 442/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 443/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 444/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0141
# Epoch 445/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 446/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0144
# Epoch 447/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 448/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 449/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 450/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 451/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 452/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 453/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 454/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0141
# Epoch 455/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0142
# Epoch 456/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0140
# Epoch 457/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 458/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 459/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 460/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 461/500
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0140
# Epoch 462/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0140
# Epoch 463/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 464/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0142
# Epoch 465/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0144
# Epoch 466/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 467/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0140
# Epoch 468/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 469/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0139
# Epoch 470/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 471/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 472/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 473/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 474/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0140
# Epoch 475/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 476/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0140
# Epoch 477/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 478/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 479/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0139
# Epoch 480/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 481/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0139
# Epoch 482/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0139
# Epoch 483/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 484/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0140
# Epoch 485/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0140
# Epoch 486/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0140
# Epoch 487/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 488/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0139
# Epoch 489/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0141
# Epoch 490/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 491/500
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0139
# Epoch 492/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0142
# Epoch 493/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0141
# Epoch 494/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0141
# Epoch 495/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0143
# Epoch 496/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0140
# Epoch 497/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141
# Epoch 498/500
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0140
# Epoch 499/500
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0139
# Epoch 500/500
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0139

# %% [markdown]
# ## Check validation result
# We will check the model's performance with validation data.

# %%
# Predict validation data using the trained model
y_pred = model.predict(X_val)
mse = MeanSquaredError()
val_err = mse(y_val.reshape(-1,1), y_pred)
print("Validation error = ", val_err.numpy())
# Return the value using inverse transform to allow better observation
plt.plot(pres_scaler.inverse_transform(y_val.reshape(-1,1)), 'k', label='Original')
plt.plot(pres_scaler.inverse_transform(y_pred.reshape(-1,1)), 'r', label='Prediction')
plt.ylabel("Pressure")
plt.xlabel("Datapoint")
plt.title("Validation data prediction")
plt.legend()
plt.show()
# Out:
# 5/5 [==============================] - 0s 3ms/step
# Validation error =  0.015006871

# %% [markdown]
# ## Check test result
#
# From the plot, we can see that some of the data points are inaccurate, which can be caused by the highly fluctuating nature of the hourly data points. Next, we will see whether the model can predict the sensor reading correctly in the event of anomalies. We are going to pick another date where failure occurred (2015-04-20).

# %%
# Select the date where another failure occurred
st_test = df_sel.loc[df_sel['datetime'] == datetime.datetime(2015, 4, 20)].index.values[0]

# Then, filter the data to include approximately two-weeks window
start_period_test = st_test - 7*24
end_period_test = st_test + 7*24
X_test, y_test, test_scaler = create_feature(start_period_test, end_period_test)

# Shape the sequence 
X_test_seq = shape_sequence(X_test, 5, 0)
y_test_seq = shape_sequence(y_test, 1, 0)

# Predict the testing data
y_pred_test = model.predict(X_test_seq)
test_err = mse(y_test_seq.reshape(-1,1), y_pred_test)
print("Testing error = ", test_err.numpy())

# Select first 200 datapoints to allow for better plotting
# Return the value using inverse transform to allow better observation
plt.plot(test_scaler.inverse_transform(y_pred_test[:200].reshape(-1, 1)), 'r', label='Prediction')
plt.plot(test_scaler.inverse_transform(y_test_seq[:200].reshape(-1, 1)), 'k', label='Original')
plt.ylabel("Pressure")
plt.xlabel("Datapoints")
plt.legend()
plt.show()
# Out:
# 11/11 [==============================] - 0s 4ms/step
# Testing error =  0.031571686

# %% [markdown]
# We observe that the model can predict the sensor reading even in the event of machine failure. The key here is to make sure that the training data that we use to train include past failure event as well.

# %% [markdown]
# # Further Steps
# Now that we know how to construct a time-series forecasting model to predict anomalies, there are several possible steps on how to develop a complete predictive maintenance solution:
# * Develop machine learning / deep learning model to predict the chance of machine breakdown by feeding it prediction results from our developed time-series forecasting model.
# * Look into signal processing algorithm to smoothen the signal before feeding it to time-series forecasting model, which could improve model's performance.
# * Use bigger subset of data in training process and check how does the model change, better or worse?
# * Do hyperparameter optimization to further optimize the performance of time-series forecasting model.

# %% [markdown]
# # Conclusion
# In this notebook, we have looked into an example predictive maintenance data from Kaggle, do some prior analysis on it, and construct a time-series forecasting model that will predict sensor reading values in the future. Hopefully, this notebook could provide some insights regarding how to implement time-series forecasting with deep learning in predictive maintenance.
